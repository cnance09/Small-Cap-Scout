# %%
import pandas as pd
import numpy as np
import glob
import os
from datetime import datetime
from pandas.errors import EmptyDataError

# %%
# Define the directory containing the .txt files
data_directory = os.path.expanduser('~/Small-Cap-Scout/raw_data/Data/Stocks')

# Define the date range
start_date = '2010-01-01'
end_date = datetime.today()

# List to hold all dataframes
all_data = []

# Use glob to find all .txt files in the specified directory
file_pattern = f"{data_directory}/*.txt"
txt_files = glob.glob(file_pattern)

# Debugging: Print the list of files found
print(f"Files found: {txt_files}")
# Out:
# Files found: ['/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/iba.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/wpz.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/opnt.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/indf.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/flic.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/nbhc.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/ncs.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/grvy.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/lgcyo.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/eqco.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/gpk.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/wti.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/dyn_a.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/cstr.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/mygn.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/cor_a-cl.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/jmu.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/jpem.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/kelya.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/wbig.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/eemx.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/nycb.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/elp.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/aieq.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/axas.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/cphi.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/thr.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/nxeow.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/vrsk.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/abil.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/evep.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/srlp.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/www.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/nnvc.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/exr.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/feye.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/rbcaa.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/enrj.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/mlnt.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/avt.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/gazb.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/dxr.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/gdi.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/ngvt.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/irix.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/pay.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/pfbx.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/hyxu.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/nlnk.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/ivc.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/mxe.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/osb.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/txrh.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/mx.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/smmd.us.txt', '/Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/mnro.us.txt', '/Users/eoingaynard/ ...

# %%
# Loop through each .txt file found
for file_path in txt_files:
    try:
        # Get the company ticker from the filename
        filename = os.path.basename(file_path)  # Get the filename from the path
        company_ticker = filename.split('.')[0]  # Extract the ticker from the filename

        # Load the data from the .txt file
        df = pd.read_csv(file_path, parse_dates=['Date'])

        # Drop all columns except 'Date', 'Volume', and 'Close'
        columns_to_keep = ['Date', 'Volume', 'Close']
        df = df[[col for col in columns_to_keep if col in df.columns]]

        # Check if required columns are present
        if 'Date' not in df.columns or 'Close' not in df.columns:
            print(f"File {filename} is missing required columns. Skipping.")
            continue

        # Debugging: Check if DataFrame is loaded properly
        print(f"Processing {company_ticker}, initial data size: {df.shape}")

        # Filter the data by date
        df = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

        # Debugging: Check if the data filtering is correct
        print(f"Filtered data size for {company_ticker}: {df.shape}")

        # Proceed only if the DataFrame is not empty
        if not df.empty:
            # Calculate the monthly average prices
            df['Month'] = df['Date'].dt.to_period('M')
            monthly_avg = df.groupby('Month')['Close'].mean().reset_index()
            monthly_avg.rename(columns={'Close': 'Monthly_Avg_Close'}, inplace=True)

            # Calculate the monthly total volume
            monthly_volume_total = df.groupby('Month')['Volume'].sum().reset_index()
            monthly_volume_total.rename(columns={'Volume': 'Monthly_Volume_Total'}, inplace=True)

            # Calculate the monthly average volume
            monthly_volume_avg = df.groupby('Month')['Volume'].mean().reset_index()
            monthly_volume_avg.rename(columns={'Volume': 'Monthly_Volume_Avg'}, inplace=True)

            # Calculate the monthly volatility
            df['Log_Return'] = df['Close'].pct_change().apply(lambda x: np.log(1+x))
            monthly_volatility = df.groupby('Month')['Log_Return'].std().reset_index()

            # Dynamically calculate the number of months for volatility scaling
            num_months = len(monthly_volatility)
            if num_months > 0:
                monthly_volatility['Monthly_Volatility'] = monthly_volatility['Log_Return'] * np.sqrt(num_months)
            else:
                monthly_volatility['Monthly_Volatility'] = np.nan  # In case of no data

            monthly_volatility.drop(columns=['Log_Return'], inplace=True)

            # Merge the monthly average, total volume, average volume, and volatility data
            result = pd.merge(monthly_avg, monthly_volume_total, on='Month', how='inner')
            result = pd.merge(result, monthly_volume_avg, on='Month', how='inner')
            result = pd.merge(result, monthly_volatility, on='Month', how='inner')
            result['Ticker'] = company_ticker

            # Rearrange columns to put 'Ticker' first
            column_order = ['Ticker'] + [col for col in result.columns if col != 'Ticker']
            result = result[column_order]

            # Append to the list
            all_data.append(result)
        else:
            print(f"No data available for {company_ticker} in the specified date range.")

    except EmptyDataError:
        print(f"File {file_path} is empty. Skipping.")
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")

# Check if there's any data to concatenate
if all_data:
    # Concatenate all data into a single dataframe
    final_df = pd.concat(all_data, ignore_index=True)

    # Save the final dataframe to a CSV file
    output_file = os.path.expanduser('~/Small-Cap-Scout/raw_data/processed_data.csv')
    final_df.to_csv(output_file, index=False)
    print(f"Data processing complete. Results saved to {output_file}.")

    # Optionally, display the first few rows of the final DataFrame
    print("First 5 rows of the processed data:")
    print(final_df.head())
else:
    print("No data to concatenate. Please check your files and filters.")
# Out:
# Processing iba, initial data size: (3199, 3)
# Filtered data size for iba: (1979, 3)
# Processing wpz, initial data size: (3081, 3)
# Filtered data size for wpz: (1979, 3)
# Processing opnt, initial data size: (53, 3)
# Filtered data size for opnt: (53, 3)
# Processing indf, initial data size: (356, 3)
# Filtered data size for indf: (356, 3)
# Processing flic, initial data size: (3006, 3)
# Filtered data size for flic: (1979, 3)
# Processing nbhc, initial data size: (1295, 3)
# Filtered data size for nbhc: (1295, 3)
# Processing ncs, initial data size: (3201, 3)
# Filtered data size for ncs: (1979, 3)
# Processing grvy, initial data size: (3076, 3)
# Filtered data size for grvy: (1896, 3)
# Processing lgcyo, initial data size: (853, 3)
# Filtered data size for lgcyo: (853, 3)
# Processing eqco, initial data size: (1331, 3)
# Filtered data size for eqco: (1331, 3)
# Processing gpk, initial data size: (3201, 3)
# Filtered data size for gpk: (1979, 3)
# Processing wti, initial data size: (3201, 3)
# Filtered data size for wti: (1979, 3)
# Processing dyn_a, initial data size: (741, 3)
# Filtered data size for dyn_a: (741, 3)
# Processing cstr, initial data size: (288, 3)
# Filtered data size for cstr: (288, 3)
# Processing mygn, initial data size: (3201, 3)
# Filtered data size for mygn: (1979, 3)
# Processing cor_a-cl, initial data size: (18, 3)
# Filtered data size for cor_a-cl: (18, 3)
# Processing jmu, initial data size: (621, 3)
# Filtered data size for jmu: (621, 3)
# Processing jpem, initial data size: (663, 3)
# Filtered data size for jpem: (663, 3)
# Processing kelya, initial data size: (3201, 3)
# Filtered data size for kelya: (1979, 3)
# Processing wbig, initial data size: (808, 3)
# Filtered data size for wbig: (808, 3)
# Processing eemx, initial data size: (157, 3)
# Filtered data size for eemx: (157, 3)
# Processing nycb, initial data size: (3201, 3)
# Filtered data size for nycb: (1979, 3)
# Processing elp, initial data size: (3201, 3)
# Filtered data size for elp: (1979, 3)
# Processing aieq, initial data size: (17, 3)
# Filtered data size for aieq: (17, 3)
# Processing axas, initial data size: (3201, 3)
# Filtered data size for axas: (1979, 3)
# Processing cphi, initial data size: (2959, 3)
# Filtered data size for cphi: (1973, 3)
# Processing thr, initial data size: (1641, 3)
# Filtered data size for thr: (1641, 3)
# Processing nxeow, initial data size: (752, 3)
# Filtered data size for nxeow: (752, 3)
# Processing vrsk, initial data size: (2040, 3)
# Filtered data size for vrsk: (1979, 3)
# Processing abil, initial data size: (470, 3)
# Filtered data size for abil: (470, 3)
# Processing evep, initial data size: (2802, 3)
# Filtered data size for evep: (1979, 3)
# Processing srlp, initial data size: (1020, 3)
# Filtered data size for srlp: (1020, 3)
# Processing www, initial data size: (3201, 3)
# Filtered data size for www: (1979, 3)
# Processing nnvc, initial data size: (1042, 3)
# Filtered data size for nnvc: (1042, 3)
# Processing exr, initial data size: (3201, 3)
# Filtered data size for exr: (1979, 3)
# Processing feye, initial data size: (1045, 3)
# Filtered data size for feye: (1045, 3)
# Processing rbcaa, initial data size: (3201, 3)
# Filtered data size for rbcaa: (1979, 3)
# Processing enrj, initial data size: (851, 3)
# Filtered data size for enrj: (851, 3)
# Processing mlnt, initial data size: (1451, 3)
# Filtered data size for mlnt: (1451, 3)
# Processing avt, initial data size: (3201, 3)
# Filtered data size for avt: (1979, 3)
# Processing gazb, initial data size: (13, 3)
# Filtered data size for gazb: (13, 3)
# Processing dxr, initial data size: (2779, 3)
# Filtered data size for dxr: (1654, 3)
# Processing gdi, initial data size: (128, 3)
# Filtered data size for gdi: (128, 3)
# Processing ngvt, initial data size: (378, 3)
# Filtered data size for ngvt: (378, 3)
# Processing irix, initial data size: (3127, 3)
# Filtered data size for irix: (1924, 3)
# Processing pay, initial data size: (3158, 3)
# Filtered data size for pay: (1979, 3)
# Processing pfbx, initial data size: (2554, 3)
# Filtered data size for pfbx: (1593, 3)
# Processing hyxu, initial data size: (1370, 3)
# Filtered data size for hyxu: (1370, 3)
# Processing nlnk, initial data size: (1508, 3)
# Filtered data size for nlnk: (1508, 3)
# Processing ivc, initial data size: (3201, 3)
# Filtered data size for ivc: (1979, 3)
# Processing mxe, initial data size: (3189, 3)
# Filtered data size for mxe: (1968, 3)
# Processing osb, initial data size: (436, 3)
# Filtered data size for osb: (436, 3)
# Processing txrh, initial data size: (3201, 3)
# Filtered data size for txrh: (1979, 3)
# Processing mx, initial data size: (1679, 3)
# Filtered data size for mx: (1679, 3)
# Processing smmd, initial data size: (84, 3)
# Filtered data size for smmd: (84, 3)
# Processing mnro, initial data size: (3201, 3)
# Filtered data size for mnro: (1979, 3)
# Processing hdez, initial data size: (287, 3)
# Filtered data size for hdez: (287, 3)
# Processing pgz, initial data size: (1105, 3)
# Filtered data size for pgz: (1105, 3)
# Processing l, initial data size: (3201, 3)
# Filtered data size for l: (1979, 3)
# Processing jasn, initial data size: (939, 3)
# Filtered data size for jasn: (939, 3)
# Processing gfy, initial data size: (3197, 3)
# Filtered data size for gfy: (1976, 3)
# Processing eim, initial data size: (1819, 3)
# Filtered data size for eim: (1819, 3)
# Processing bll, initial data size: (8363, 3)
# Filtered data size for bll: (1980, 3)
# Processing pci, initial data size: (1208, 3)
# Filtered data size for pci: (1208, 3)
# Processing born, initial data size: (1869, 3)
# Filtered data size for born: (1869, 3)
# Processing ribtw, initial data size: (641, 3)
# Filtered data size for ribtw: (641, 3)
# Processing cizn, initial data size: (2285, 3)
# Filtered data size for cizn: (1574, 3)
# Processing usau, initial data size: (3172, 3)
# Filtered data size for usau: (1955, 3)
# Processing brkr, initial data size: (3201, 3)
# Filtered data size for brkr: (1979, 3)
# Processing tmo, initial data size: (7612, 3)
# Filtered data size for tmo: (1980, 3)
# Processing nee_j, initial data size: (1213, 3)
# Filtered data size for nee_j: (1213, 3)
# Processing clns_b, initial data size: (211, 3)
# Filtered data size for clns_b: (211, 3)
# Processing cmct, initial data size: (3147, 3)
# Filtered data size for cmct: (1925, 3)
# Processing mmi, initial data size: (1016, 3)
# Filtered data size for mmi: (1016, 3)
# Processing stor, initial data size: (752, 3)
# Filtered data size for stor: (752, 3)
# Processing clct, initial data size: (3200, 3)
# Filtered data size for clct: (1979, 3)
# Processing fuv, initial data size: (36, 3)
# Filtered data size for fuv: (36, 3)
# Processing pdlb, initial data size: (30, 3)
# Filtered data size for pdlb: (30, 3)
# Processing oilb, initial data size: (89, 3)
# Filtered data size for oilb: (89, 3)
# Processing tgen, initial data size: (832, 3)
# Filtered data size for tgen: (832, 3)
# Processing fat, initial data size: (15, 3)
# Filtered data size for fat: (15, 3)
# Processing cma-ws, initial data size: (1740, 3)
# Filtered data size for cma-ws: (1740, 3)
# Processing he, initial data size: (3201, 3)
# Filtered data size for he: (1979, 3)
# Processing wyde, initial data size: (708, 3)
# Filtered data size for wyde: (708, 3)
# Processing cor, initial data size: (1795, 3)
# Filtered data size for cor: (1795, 3)
# Processing imkta, initial data size: (3201, 3)
# Filtered data size for imkta: (1979, 3)
# Processing nep, initial data size: (852, 3)
# Filtered data size for nep: (852, 3)
# Processing ddbi, initial data size: (317, 3)
# Filtered data size for ddbi: (317, 3)
# Processing flks, initial data size: (704, 3)
# Filtered data size for flks: (704, 3)
# Processing emxc, initial data size: (47, 3)
# Filtered data size for emxc: (47, 3)
# Processing nac, initial data size: (3201, 3)
# Filtered data size for nac: (1979, 3)
# Processing dfin, initial data size: (280, 3)
# Filtered data size for dfin: (280, 3)
# Processing psx, initial data size: (1392, 3)
# Filtered data size for psx: (1392, 3)
# Processing atacu, initial data size: (44, 3)
# Filtered data size for atacu: (44, 3)
# Processing joe, initial data size: (3201, 3)
# Filtered data size for joe: (1979, 3)
# Processing hdb, initial data size: (3201, 3)
# Filtered data size for hdb: (1979, 3)
# Processing agn_a, initial data size: (610, 3)
# Filtered data size for agn_a: (610, 3)
# Processing rexr_a, initial data size: (299, 3)
# Filtered data size for rexr_a: (299, 3)
# Processing jhd, initial data size: (381, 3)
# Filtered data size for jhd: (381, 3)
# Processing wpcs, initial data size: (3162, 3)
# Filtered data size for wpcs: (1950, 3)
# Processing ath, initial data size: (233, 3)
# Filtered data size for ath: (233, 3)
# Processing tapr, initial data size: (711, 3)
# Filtered data size for tapr: (711, 3)
# Processing yrcw, initial data size: (1474, 3)
# Filtered data size for yrcw: (1474, 3)
# Processing hcc, initial data size: (148, 3)
# Filtered data size for hcc: (148, 3)
# Processing sivb, initial data size: (3201, 3)
# Filtered data size for sivb: (1979, 3)
# Processing fncf, initial data size: (354, 3)
# Filtered data size for fncf: (354, 3)
# Processing igro, initial data size: (369, 3)
# Filtered data size for igro: (369, 3)
# Processing coll, initial data size: (635, 3)
# Filtered data size for coll: (635, 3)
# Processing pty, initial data size: (3201, 3)
# Filtered data size for pty: (1979, 3)
# Processing dmrc, initial data size: (2283, 3)
# Filtered data size for dmrc: (1979, 3)
# Processing kmpr, initial data size: (1564, 3)
# Filtered data size for kmpr: (1564, 3)
# Processing kw, initial data size: (2393, 3)
# Filtered data size for kw: (1978, 3)
# Processing ceco, initial data size: (4946, 3)
# Filtered data size for ceco: (1980, 3)
# Processing asb-ws, initial data size: (332, 3)
# Filtered data size for asb-ws: (332, 3)
# Processing sfst, initial data size: (2725, 3)
# Filtered data size for sfst: (1700, 3)
# Processing chs, initial data size: (3201, 3)
# Filtered data size for chs: (1979, 3)
# Processing tslx, initial data size: (920, 3)
# Filtered data size for tslx: (920, 3)
# Processing umc, initial data size: (3201, 3)
# Filtered data size for umc: (1979, 3)
# Processing eia, initial data size: (3189, 3)
# Filtered data size for eia: (1979, 3)
# Processing num, initial data size: (3200, 3)
# Filtered data size for num: (1979, 3)
# Processing fult, initial data size: (3201, 3)
# Filtered data size for fult: (1979, 3)
# Processing fele, initial data size: (3201, 3)
# Filtered data size for fele: (1979, 3)
# Processing evtc, initial data size: (1157, 3)
# Filtered data size for evtc: (1157, 3)
# Processing emr, initial data size: (9044, 3)
# Filtered data size for emr: (1980, 3)
# Processing jbht, initial data size: (3201, 3)
# Filtered data size for jbht: (1979, 3)
# Processing ofix, initial data size: (3201, 3)
# Filtered data size for ofix: (1979, 3)
# Processing achn, initial data size: (2780, 3)
# Filtered data size for achn: (1979, 3)
# Processing cbrl, initial data size: (3201, 3)
# Filtered data size for cbrl: (1979, 3)
# Processing odfl, initial data size: (3202, 3)
# Filtered data size for odfl: (1980, 3)
# Processing bracr, initial data size: (11, 3)
# Filtered data size for bracr: (11, 3)
# Processing zlab, initial data size: (38, 3)
# Filtered data size for zlab: (38, 3)
# Processing nao, initial data size: (863, 3)
# Filtered data size for nao: (863, 3)
# Processing induw, initial data size: (50, 3)
# Filtered data size for induw: (50, 3)
# Processing idn, initial data size: (3194, 3)
# Filtered data size for idn: (1976, 3)
# Processing ggzr, initial data size: (11, 3)
# Filtered data size for ggzr: (11, 3)
# Processing heww, initial data size: (164, 3)
# Filtered data size for heww: (164, 3)
# Processing ctso, initial data size: (2217, 3)
# Filtered data size for ctso: (1980, 3)
# File /Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/pbio.us.txt is empty. Skipping.
# Processing fqal, initial data size: (291, 3)
# Filtered data size for fqal: (291, 3)
# Processing fax, initial data size: (3201, 3)
# Filtered data size for fax: (1979, 3)
# Processing cnxn, initial data size: (3201, 3)
# Filtered data size for cnxn: (1979, 3)
# Processing hi, initial data size: (2430, 3)
# Filtered data size for hi: (1979, 3)
# Processing dlbr, initial data size: (22, 3)
# Filtered data size for dlbr: (22, 3)
# Processing psmm, initial data size: (174, 3)
# Filtered data size for psmm: (174, 3)
# Processing sncr, initial data size: (2874, 3)
# Filtered data size for sncr: (1979, 3)
# Processing lscc, initial data size: (3201, 3)
# Filtered data size for lscc: (1979, 3)
# Processing isr, initial data size: (3037, 3)
# Filtered data size for isr: (1979, 3)
# Processing lyg, initial data size: (3201, 3)
# Filtered data size for lyg: (1979, 3)
# Processing aezs, initial data size: (3201, 3)
# Filtered data size for aezs: (1979, 3)
# Processing gek, initial data size: (1130, 3)
# Filtered data size for gek: (1130, 3)
# Processing nvs, initial data size: (3201, 3)
# Filtered data size for nvs: (1979, 3)
# Processing afi, initial data size: (407, 3)
# Filtered data size for afi: (407, 3)
# Processing afsd, initial data size: (1290, 3)
# Filtered data size for afsd: (1290, 3)
# Processing opp, initial data size: (282, 3)
# Filtered data size for opp: (282, 3)
# Processing hcci, initial data size: (2415, 3)
# Filtered data size for hcci: (1977, 3)
# Processing gddy, initial data size: (661, 3)
# Filtered data size for gddy: (661, 3)
# Processing ghyg, initial data size: (1364, 3)
# Filtered data size for ghyg: (1364, 3)
# Processing ipoa-ws, initial data size: (29, 3)
# Filtered data size for ipoa-ws: (29, 3)
# Processing gch, initial data size: (3200, 3)
# Filtered data size for gch: (1978, 3)
# Processing loxo, initial data size: (828, 3)
# Filtered data size for loxo: (828, 3)
# Processing ibkcp, initial data size: (551, 3)
# Filtered data size for ibkcp: (551, 3)
# Processing mchp, initial data size: (6208, 3)
# Filtered data size for mchp: (1980, 3)
# Processing bsjp, initial data size: (28, 3)
# Filtered data size for bsjp: (28, 3)
# Processing ntc, initial data size: (3175, 3)
# Filtered data size for ntc: (1974, 3)
# Processing rnlc, initial data size: (61, 3)
# Filtered data size for rnlc: (61, 3)
# Processing szc, initial data size: (1291, 3)
# Filtered data size for szc: (1291, 3)
# Processing vlrs, initial data size: (1047, 3)
# Filtered data size for vlrs: (1047, 3)
# Processing vpv, initial data size: (3190, 3)
# Filtered data size for vpv: (1979, 3)
# Processing ivr_a, initial data size: (1332, 3)
# Filtered data size for ivr_a: (1332, 3)
# Processing hbm, initial data size: (3039, 3)
# Filtered data size for hbm: (1965, 3)
# Processing dtla_, initial data size: (674, 3)
# Filtered data size for dtla_: (674, 3)
# Processing imom, initial data size: (453, 3)
# Filtered data size for imom: (453, 3)
# Processing pgre, initial data size: (751, 3)
# Filtered data size for pgre: (751, 3)
# Processing nhtc, initial data size: (691, 3)
# Filtered data size for nhtc: (691, 3)
# Processing czr, initial data size: (1449, 3)
# Filtered data size for czr: (1449, 3)
# Processing eqgp, initial data size: (633, 3)
# Filtered data size for eqgp: (633, 3)
# Processing comb, initial data size: (111, 3)
# Filtered data size for comb: (111, 3)
# Processing gtt, initial data size: (1105, 3)
# Filtered data size for gtt: (1105, 3)
# Processing ngl, initial data size: (1636, 3)
# Filtered data size for ngl: (1636, 3)
# Processing ibm, initial data size: (14059, 3)
# Filtered data size for ibm: (1980, 3)
# Processing zyme, initial data size: (138, 3)
# Filtered data size for zyme: (138, 3)
# Processing flio, initial data size: (91, 3)
# Filtered data size for flio: (91, 3)
# Processing stlru, initial data size: (88, 3)
# Filtered data size for stlru: (88, 3)
# Processing anss, initial data size: (3201, 3)
# Filtered data size for anss: (1979, 3)
# Processing ubsi, initial data size: (3201, 3)
# Filtered data size for ubsi: (1979, 3)
# Processing cnp, initial data size: (12072, 3)
# Filtered data size for cnp: (1979, 3)
# Processing sofo, initial data size: (3117, 3)
# Filtered data size for sofo: (1895, 3)
# Processing gaia, initial data size: (3200, 3)
# Filtered data size for gaia: (1979, 3)
# Processing wlkp, initial data size: (830, 3)
# Filtered data size for wlkp: (830, 3)
# Processing sjr, initial data size: (3201, 3)
# Filtered data size for sjr: (1979, 3)
# Processing mt, initial data size: (3201, 3)
# Filtered data size for mt: (1979, 3)
# Processing osn, initial data size: (1628, 3)
# Filtered data size for osn: (1628, 3)
# Processing gamr, initial data size: (414, 3)
# Filtered data size for gamr: (414, 3)
# Processing sna, initial data size: (8158, 3)
# Filtered data size for sna: (1980, 3)
# Processing xrm, initial data size: (3145, 3)
# Filtered data size for xrm: (1977, 3)
# Processing marps, initial data size: (3047, 3)
# Filtered data size for marps: (1889, 3)
# Processing hcapz, initial data size: (50, 3)
# Filtered data size for hcapz: (50, 3)
# Processing fisk, initial data size: (618, 3)
# Filtered data size for fisk: (618, 3)
# Processing fund, initial data size: (3201, 3)
# Filtered data size for fund: (1979, 3)
# Processing ancb, initial data size: (1366, 3)
# Filtered data size for ancb: (1366, 3)
# Processing asmb, initial data size: (1735, 3)
# Filtered data size for asmb: (1735, 3)
# Processing fmnb, initial data size: (1543, 3)
# Filtered data size for fmnb: (1543, 3)
# Processing avx, initial data size: (3201, 3)
# Filtered data size for avx: (1979, 3)
# Processing mlnx, initial data size: (2711, 3)
# Filtered data size for mlnx: (1979, 3)
# Processing deck, initial data size: (3201, 3)
# Filtered data size for deck: (1979, 3)
# Processing vsh, initial data size: (3201, 3)
# Filtered data size for vsh: (1979, 3)
# Processing pnfp, initial data size: (3201, 3)
# Filtered data size for pnfp: (1979, 3)
# Processing has, initial data size: (8294, 3)
# Filtered data size for has: (1980, 3)
# Processing aehr, initial data size: (3119, 3)
# Filtered data size for aehr: (1931, 3)
# Processing ahp_b, initial data size: (307, 3)
# Filtered data size for ahp_b: (307, 3)
# Processing iagg, initial data size: (497, 3)
# Filtered data size for iagg: (497, 3)
# Processing lb, initial data size: (8160, 3)
# Filtered data size for lb: (1980, 3)
# Processing pbmd, initial data size: (1311, 3)
# Filtered data size for pbmd: (1311, 3)
# Processing cof, initial data size: (5784, 3)
# Filtered data size for cof: (1979, 3)
# Processing ent, initial data size: (1338, 3)
# Filtered data size for ent: (1338, 3)
# Processing bku, initial data size: (1707, 3)
# Filtered data size for bku: (1707, 3)
# Processing rpxc, initial data size: (1642, 3)
# Filtered data size for rpxc: (1642, 3)
# Processing fivn, initial data size: (910, 3)
# Filtered data size for fivn: (910, 3)
# Processing web, initial data size: (3028, 3)
# Filtered data size for web: (1979, 3)
# Processing ges, initial data size: (3201, 3)
# Filtered data size for ges: (1979, 3)
# Processing pdp, initial data size: (2696, 3)
# Filtered data size for pdp: (1979, 3)
# Processing lvin, initial data size: (123, 3)
# Filtered data size for lvin: (123, 3)
# Processing fxep, initial data size: (34, 3)
# Filtered data size for fxep: (34, 3)
# Processing ahpi, initial data size: (2854, 3)
# Filtered data size for ahpi: (1742, 3)
# Processing tast, initial data size: (2746, 3)
# Filtered data size for tast: (1979, 3)
# Processing achv, initial data size: (3200, 3)
# Filtered data size for achv: (1979, 3)
# Processing fro, initial data size: (3201, 3)
# Filtered data size for fro: (1979, 3)
# Processing ftxn, initial data size: (155, 3)
# Filtered data size for ftxn: (155, 3)
# Processing wbkc, initial data size: (1108, 3)
# Filtered data size for wbkc: (1108, 3)
# Processing jack, initial data size: (3201, 3)
# Filtered data size for jack: (1979, 3)
# Processing pcg_g, initial data size: (993, 3)
# Filtered data size for pcg_g: (993, 3)
# Processing ueps, initial data size: (3201, 3)
# Filtered data size for ueps: (1979, 3)
# Processing nly_d, initial data size: (1296, 3)
# Filtered data size for nly_d: (1296, 3)
# Processing grpn, initial data size: (1514, 3)
# Filtered data size for grpn: (1514, 3)
# Processing scacw, initial data size: (111, 3)
# Filtered data size for scacw: (111, 3)
# Processing xtlb, initial data size: (884, 3)
# Filtered data size for xtlb: (884, 3)
# Processing jagx, initial data size: (628, 3)
# Filtered data size for jagx: (628, 3)
# Processing ophc, initial data size: (2161, 3)
# Filtered data size for ophc: (1604, 3)
# Processing psl, initial data size: (2760, 3)
# Filtered data size for psl: (1956, 3)
# Processing lnc, initial data size: (8345, 3)
# Filtered data size for lnc: (1980, 3)
# Processing ko, initial data size: (12075, 3)
# Filtered data size for ko: (1980, 3)
# Processing mza, initial data size: (3121, 3)
# Filtered data size for mza: (1943, 3)
# Processing cbfv, initial data size: (676, 3)
# Filtered data size for cbfv: (676, 3)
# Processing clx, initial data size: (8736, 3)
# Filtered data size for clx: (1979, 3)
# Processing hpt, initial data size: (3201, 3)
# Filtered data size for hpt: (1979, 3)
# Processing mntx, initial data size: (3124, 3)
# Filtered data size for mntx: (1979, 3)
# Processing nvta, initial data size: (694, 3)
# Filtered data size for nvta: (694, 3)
# Processing chk, initial data size: (3201, 3)
# Filtered data size for chk: (1979, 3)
# Processing xgtiw, initial data size: (10, 3)
# Filtered data size for xgtiw: (10, 3)
# Processing blx, initial data size: (3201, 3)
# Filtered data size for blx: (1979, 3)
# Processing bxp_b, initial data size: (1162, 3)
# Filtered data size for bxp_b: (1162, 3)
# Processing mvcb, initial data size: (1148, 3)
# Filtered data size for mvcb: (1148, 3)
# Processing x, initial data size: (6697, 3)
# Filtered data size for x: (1980, 3)
# Processing lbrda, initial data size: (760, 3)
# Filtered data size for lbrda: (760, 3)
# Processing emj, initial data size: (3169, 3)
# Filtered data size for emj: (1975, 3)
# Processing bhk, initial data size: (3201, 3)
# Filtered data size for bhk: (1979, 3)
# Processing itg, initial data size: (3201, 3)
# Filtered data size for itg: (1979, 3)
# Processing jpm_h, initial data size: (570, 3)
# Filtered data size for jpm_h: (570, 3)
# Processing rli, initial data size: (3201, 3)
# Filtered data size for rli: (1979, 3)
# Processing spro, initial data size: (7, 3)
# Filtered data size for spro: (7, 3)
# Processing titn, initial data size: (2502, 3)
# Filtered data size for titn: (1979, 3)
# Processing hgh, initial data size: (1398, 3)
# Filtered data size for hgh: (1398, 3)
# Processing ssnt, initial data size: (143, 3)
# Filtered data size for ssnt: (143, 3)
# Processing thga, initial data size: (1166, 3)
# Filtered data size for thga: (1166, 3)
# Processing nvgn, initial data size: (1437, 3)
# Filtered data size for nvgn: (1437, 3)
# Processing asb_c, initial data size: (595, 3)
# Filtered data size for asb_c: (595, 3)
# Processing apc, initial data size: (7855, 3)
# Filtered data size for apc: (1980, 3)
# Processing min, initial data size: (3201, 3)
# Filtered data size for min: (1979, 3)
# Processing atnx, initial data size: (106, 3)
# Filtered data size for atnx: (106, 3)
# Processing aval, initial data size: (792, 3)
# Filtered data size for aval: (792, 3)
# Processing ltrx, initial data size: (3115, 3)
# Filtered data size for ltrx: (1913, 3)
# Processing ppr, initial data size: (3201, 3)
# Filtered data size for ppr: (1979, 3)
# Processing mmlp, initial data size: (3201, 3)
# Filtered data size for mmlp: (1979, 3)
# Processing ktcc, initial data size: (3197, 3)
# Filtered data size for ktcc: (1979, 3)
# Processing banc_d, initial data size: (654, 3)
# Filtered data size for banc_d: (654, 3)
# Processing gainn, initial data size: (563, 3)
# Filtered data size for gainn: (563, 3)
# Processing siri, initial data size: (3201, 3)
# Filtered data size for siri: (1979, 3)
# Processing dtea, initial data size: (616, 3)
# Filtered data size for dtea: (616, 3)
# Processing lone, initial data size: (343, 3)
# Filtered data size for lone: (343, 3)
# Processing agen, initial data size: (3201, 3)
# Filtered data size for agen: (1979, 3)
# Processing sfbs, initial data size: (883, 3)
# Filtered data size for sfbs: (883, 3)
# Processing hlm_, initial data size: (1797, 3)
# Filtered data size for hlm_: (1797, 3)
# Processing dwlv, initial data size: (247, 3)
# Filtered data size for dwlv: (247, 3)
# Processing avgo, initial data size: (2083, 3)
# Filtered data size for avgo: (1979, 3)
# Processing dmtx, initial data size: (515, 3)
# Filtered data size for dmtx: (515, 3)
# Processing iex, initial data size: (3201, 3)
# Filtered data size for iex: (1979, 3)
# Processing hurc, initial data size: (3201, 3)
# Filtered data size for hurc: (1979, 3)
# Processing semg, initial data size: (1890, 3)
# Filtered data size for semg: (1890, 3)
# Processing redu, initial data size: (16, 3)
# Filtered data size for redu: (16, 3)
# Processing arii, initial data size: (2975, 3)
# Filtered data size for arii: (1979, 3)
# Processing chke, initial data size: (3201, 3)
# Filtered data size for chke: (1979, 3)
# Processing gwr, initial data size: (3201, 3)
# Filtered data size for gwr: (1979, 3)
# Processing thrm, initial data size: (3200, 3)
# Filtered data size for thrm: (1979, 3)
# Processing wexp, initial data size: (12, 3)
# Filtered data size for wexp: (12, 3)
# Processing sny, initial data size: (3201, 3)
# Filtered data size for sny: (1979, 3)
# Processing evstc, initial data size: (367, 3)
# Filtered data size for evstc: (367, 3)
# Processing qbak, initial data size: (2896, 3)
# Filtered data size for qbak: (1780, 3)
# Processing wprt, initial data size: (2894, 3)
# Filtered data size for wprt: (1979, 3)
# Processing aeo, initial data size: (3201, 3)
# Filtered data size for aeo: (1979, 3)
# Processing angi, initial data size: (1504, 3)
# Filtered data size for angi: (1504, 3)
# Processing nwe, initial data size: (3201, 3)
# Filtered data size for nwe: (1979, 3)
# Processing resi, initial data size: (1229, 3)
# Filtered data size for resi: (1229, 3)
# Processing sptl, initial data size: (2592, 3)
# Filtered data size for sptl: (1975, 3)
# Processing kona, initial data size: (3079, 3)
# Filtered data size for kona: (1979, 3)
# Processing intc, initial data size: (11556, 3)
# Filtered data size for intc: (1980, 3)
# Processing pam, initial data size: (2037, 3)
# Filtered data size for pam: (1979, 3)
# Processing alp_o-cl, initial data size: (22, 3)
# Filtered data size for alp_o-cl: (22, 3)
# Processing bio-b, initial data size: (45, 3)
# Filtered data size for bio-b: (45, 3)
# Processing asnd, initial data size: (705, 3)
# Filtered data size for asnd: (705, 3)
# Processing numg, initial data size: (207, 3)
# Filtered data size for numg: (207, 3)
# Processing c_j, initial data size: (1039, 3)
# Filtered data size for c_j: (1039, 3)
# Processing iff, initial data size: (9043, 3)
# Filtered data size for iff: (1980, 3)
# Processing smg, initial data size: (3201, 3)
# Filtered data size for smg: (1979, 3)
# Processing vgr, initial data size: (3201, 3)
# Filtered data size for vgr: (1979, 3)
# Processing nr, initial data size: (3201, 3)
# Filtered data size for nr: (1979, 3)
# Processing cie, initial data size: (1991, 3)
# Filtered data size for cie: (1979, 3)
# Processing plym, initial data size: (109, 3)
# Filtered data size for plym: (109, 3)
# Processing htfa, initial data size: (27, 3)
# Filtered data size for htfa: (27, 3)
# Processing abb, initial data size: (3201, 3)
# Filtered data size for abb: (1979, 3)
# Processing gcp, initial data size: (447, 3)
# Filtered data size for gcp: (447, 3)
# Processing oesx, initial data size: (2493, 3)
# Filtered data size for oesx: (1979, 3)
# Processing tntr, initial data size: (94, 3)
# Filtered data size for tntr: (94, 3)
# Processing pvac, initial data size: (214, 3)
# Filtered data size for pvac: (214, 3)
# Processing spwr, initial data size: (1505, 3)
# Filtered data size for spwr: (1505, 3)
# Processing glu_a, initial data size: (650, 3)
# Filtered data size for glu_a: (650, 3)
# Processing skln, initial data size: (1616, 3)
# Filtered data size for skln: (1616, 3)
# Processing rjf, initial data size: (3201, 3)
# Filtered data size for rjf: (1979, 3)
# Processing per, initial data size: (1573, 3)
# Filtered data size for per: (1573, 3)
# Processing kyo, initial data size: (3201, 3)
# Filtered data size for kyo: (1979, 3)
# Processing urgn, initial data size: (134, 3)
# Filtered data size for urgn: (134, 3)
# Processing sigi, initial data size: (3201, 3)
# Filtered data size for sigi: (1979, 3)
# Processing gdl_b, initial data size: (1296, 3)
# Filtered data size for gdl_b: (1296, 3)
# Processing paa, initial data size: (3201, 3)
# Filtered data size for paa: (1979, 3)
# Processing aap, initial data size: (3201, 3)
# Filtered data size for aap: (1979, 3)
# Processing gsbc, initial data size: (3201, 3)
# Filtered data size for gsbc: (1979, 3)
# Processing form, initial data size: (3201, 3)
# Filtered data size for form: (1979, 3)
# Processing cubi_e, initial data size: (376, 3)
# Filtered data size for cubi_e: (376, 3)
# Processing mtb_, initial data size: (16, 3)
# Filtered data size for mtb_: (16, 3)
# Processing dov, initial data size: (8160, 3)
# Filtered data size for dov: (1980, 3)
# Processing jsml, initial data size: (362, 3)
# Filtered data size for jsml: (362, 3)
# Processing gsm, initial data size: (2088, 3)
# Filtered data size for gsm: (1979, 3)
# Processing qcrh, initial data size: (2919, 3)
# Filtered data size for qcrh: (1882, 3)
# Processing ryi, initial data size: (823, 3)
# Filtered data size for ryi: (823, 3)
# Processing ulbi, initial data size: (3197, 3)
# Filtered data size for ulbi: (1975, 3)
# Processing ecol, initial data size: (3201, 3)
# Filtered data size for ecol: (1979, 3)
# Processing lcut, initial data size: (3201, 3)
# Filtered data size for lcut: (1979, 3)
# Processing iag, initial data size: (3201, 3)
# Filtered data size for iag: (1979, 3)
# Processing fsm, initial data size: (1548, 3)
# Filtered data size for fsm: (1548, 3)
# Processing kgji, initial data size: (2278, 3)
# Filtered data size for kgji: (1927, 3)
# Processing nfec, initial data size: (2386, 3)
# Filtered data size for nfec: (1915, 3)
# Processing enva, initial data size: (752, 3)
# Filtered data size for enva: (752, 3)
# Processing vktx, initial data size: (642, 3)
# Filtered data size for vktx: (642, 3)
# Processing ipay, initial data size: (571, 3)
# Filtered data size for ipay: (571, 3)
# Processing trmb, initial data size: (3201, 3)
# Filtered data size for trmb: (1979, 3)
# Processing spsm, initial data size: (1075, 3)
# Filtered data size for spsm: (1075, 3)
# Processing nick, initial data size: (3168, 3)
# Filtered data size for nick: (1966, 3)
# Processing ggo, initial data size: (61, 3)
# Filtered data size for ggo: (61, 3)
# Processing jsyn, initial data size: (246, 3)
# Filtered data size for jsyn: (246, 3)
# Processing pfl, initial data size: (3201, 3)
# Filtered data size for pfl: (1979, 3)
# Processing xlnx, initial data size: (6905, 3)
# Filtered data size for xlnx: (1980, 3)
# Processing lret, initial data size: (549, 3)
# Filtered data size for lret: (549, 3)
# Processing cii, initial data size: (3201, 3)
# Filtered data size for cii: (1979, 3)
# Processing usdp, initial data size: (780, 3)
# Filtered data size for usdp: (780, 3)
# Processing six, initial data size: (1891, 3)
# Filtered data size for six: (1891, 3)
# Processing plya, initial data size: (170, 3)
# Filtered data size for plya: (170, 3)
# Processing pgem, initial data size: (1128, 3)
# Filtered data size for pgem: (1128, 3)
# Processing kmm, initial data size: (3201, 3)
# Filtered data size for kmm: (1979, 3)
# Processing heus, initial data size: (437, 3)
# Filtered data size for heus: (437, 3)
# Processing kalv, initial data size: (654, 3)
# Filtered data size for kalv: (654, 3)
# Processing nwfl, initial data size: (2505, 3)
# Filtered data size for nwfl: (1726, 3)
# Processing gps, initial data size: (7640, 3)
# Filtered data size for gps: (1980, 3)
# Processing expo, initial data size: (3201, 3)
# Filtered data size for expo: (1979, 3)
# Processing mict, initial data size: (1027, 3)
# Filtered data size for mict: (1027, 3)
# Processing jpeu, initial data size: (318, 3)
# Filtered data size for jpeu: (318, 3)
# Processing nclh, initial data size: (1214, 3)
# Filtered data size for nclh: (1214, 3)
# Processing jmm, initial data size: (3198, 3)
# Filtered data size for jmm: (1977, 3)
# Processing homl, initial data size: (393, 3)
# Filtered data size for homl: (393, 3)
# Processing sckt, initial data size: (351, 3)
# Filtered data size for sckt: (351, 3)
# Processing linu, initial data size: (2044, 3)
# Filtered data size for linu: (1926, 3)
# Processing fate, initial data size: (1037, 3)
# Filtered data size for fate: (1037, 3)
# Processing infn, initial data size: (2629, 3)
# Filtered data size for infn: (1979, 3)
# Processing gvp, initial data size: (3150, 3)
# Filtered data size for gvp: (1970, 3)
# Processing ziop, initial data size: (2966, 3)
# Filtered data size for ziop: (1979, 3)
# Processing hewc, initial data size: (277, 3)
# Filtered data size for hewc: (277, 3)
# Processing grc, initial data size: (3201, 3)
# Filtered data size for grc: (1979, 3)
# Processing dvmt, initial data size: (298, 3)
# Filtered data size for dvmt: (298, 3)
# Processing bvxvw, initial data size: (364, 3)
# Filtered data size for bvxvw: (364, 3)
# Processing husa, initial data size: (3175, 3)
# Filtered data size for husa: (1978, 3)
# Processing bnft, initial data size: (1047, 3)
# Filtered data size for bnft: (1047, 3)
# Processing veco, initial data size: (3201, 3)
# Filtered data size for veco: (1979, 3)
# Processing frc, initial data size: (1741, 3)
# Filtered data size for frc: (1741, 3)
# Processing qure, initial data size: (951, 3)
# Filtered data size for qure: (951, 3)
# Processing mosy, initial data size: (3201, 3)
# Filtered data size for mosy: (1979, 3)
# Processing ipci, initial data size: (3195, 3)
# Filtered data size for ipci: (1976, 3)
# Processing nrt, initial data size: (3201, 3)
# Filtered data size for nrt: (1979, 3)
# Processing skis, initial data size: (749, 3)
# Filtered data size for skis: (749, 3)
# Processing enx, initial data size: (3201, 3)
# Filtered data size for enx: (1979, 3)
# Processing clirw, initial data size: (143, 3)
# Filtered data size for clirw: (143, 3)
# Processing wen, initial data size: (8723, 3)
# Filtered data size for wen: (1980, 3)
# Processing isf, initial data size: (1819, 3)
# Filtered data size for isf: (1819, 3)
# Processing brk-b, initial data size: (5415, 3)
# Filtered data size for brk-b: (1979, 3)
# Processing lsxmb, initial data size: (108, 3)
# Filtered data size for lsxmb: (108, 3)
# Processing nvg, initial data size: (3201, 3)
# Filtered data size for nvg: (1979, 3)
# Processing spun, initial data size: (329, 3)
# Filtered data size for spun: (329, 3)
# Processing adm, initial data size: (8726, 3)
# Filtered data size for adm: (1980, 3)
# Processing ln, initial data size: (337, 3)
# Filtered data size for ln: (337, 3)
# Processing batra, initial data size: (398, 3)
# Filtered data size for batra: (398, 3)
# Processing wage, initial data size: (1387, 3)
# Filtered data size for wage: (1387, 3)
# Processing igd, initial data size: (3181, 3)
# Filtered data size for igd: (1979, 3)
# Processing nee_r, initial data size: (301, 3)
# Filtered data size for nee_r: (301, 3)
# Processing jcom, initial data size: (3201, 3)
# Filtered data size for jcom: (1979, 3)
# Processing cmcl, initial data size: (74, 3)
# Filtered data size for cmcl: (74, 3)
# Processing vsar, initial data size: (920, 3)
# Filtered data size for vsar: (920, 3)
# Processing obe, initial data size: (3188, 3)
# Filtered data size for obe: (1979, 3)
# Processing wrls, initial data size: (54, 3)
# Filtered data size for wrls: (54, 3)
# Processing ebio, initial data size: (950, 3)
# Filtered data size for ebio: (950, 3)
# Processing fun, initial data size: (3201, 3)
# Filtered data size for fun: (1979, 3)
# Processing xl, initial data size: (4837, 3)
# Filtered data size for xl: (1980, 3)
# Processing apo, initial data size: (1664, 3)
# Filtered data size for apo: (1664, 3)
# Processing qtm, initial data size: (3201, 3)
# Filtered data size for qtm: (1979, 3)
# Processing ffty, initial data size: (618, 3)
# Filtered data size for ffty: (618, 3)
# Processing axs_d, initial data size: (1127, 3)
# Filtered data size for axs_d: (1127, 3)
# Processing gfa, initial data size: (2685, 3)
# Filtered data size for gfa: (1979, 3)
# Processing wbc, initial data size: (2601, 3)
# Filtered data size for wbc: (1979, 3)
# Processing t, initial data size: (8401, 3)
# Filtered data size for t: (1980, 3)
# Processing emf, initial data size: (3201, 3)
# Filtered data size for emf: (1979, 3)
# Processing gbr, initial data size: (2794, 3)
# Filtered data size for gbr: (1841, 3)
# Processing jpm_d, initial data size: (1297, 3)
# Filtered data size for jpm_d: (1297, 3)
# Processing pcq, initial data size: (3201, 3)
# Filtered data size for pcq: (1979, 3)
# Processing htgc, initial data size: (3129, 3)
# Filtered data size for htgc: (1979, 3)
# Processing omab, initial data size: (2752, 3)
# Filtered data size for omab: (1973, 3)
# Processing fbr, initial data size: (3201, 3)
# Filtered data size for fbr: (1979, 3)
# Processing dmf, initial data size: (3201, 3)
# Filtered data size for dmf: (1979, 3)
# Processing pei_b, initial data size: (1193, 3)
# Filtered data size for pei_b: (1193, 3)
# Processing gfnsl, initial data size: (816, 3)
# Filtered data size for gfnsl: (816, 3)
# Processing splk, initial data size: (1402, 3)
# Filtered data size for splk: (1402, 3)
# Processing bcv_a, initial data size: (274, 3)
# Filtered data size for bcv_a: (274, 3)
# Processing gdv_g, initial data size: (341, 3)
# Filtered data size for gdv_g: (341, 3)
# Processing hnp, initial data size: (3194, 3)
# Filtered data size for hnp: (1972, 3)
# Processing icui, initial data size: (3201, 3)
# Filtered data size for icui: (1979, 3)
# Processing prpo, initial data size: (93, 3)
# Filtered data size for prpo: (93, 3)
# Processing cvo, initial data size: (3201, 3)
# Filtered data size for cvo: (1979, 3)
# Processing merc, initial data size: (3201, 3)
# Filtered data size for merc: (1979, 3)
# Processing nee_c-cl, initial data size: (21, 3)
# Filtered data size for nee_c-cl: (21, 3)
# Processing acfc, initial data size: (1552, 3)
# Filtered data size for acfc: (1552, 3)
# Processing auto, initial data size: (3199, 3)
# Filtered data size for auto: (1977, 3)
# Processing rndm, initial data size: (66, 3)
# Filtered data size for rndm: (66, 3)
# Processing jhmi, initial data size: (193, 3)
# Filtered data size for jhmi: (193, 3)
# Processing fsacu, initial data size: (64, 3)
# Filtered data size for fsacu: (64, 3)
# Processing bas, initial data size: (3002, 3)
# Filtered data size for bas: (1979, 3)
# Processing edr, initial data size: (3201, 3)
# Filtered data size for edr: (1979, 3)
# Processing trex, initial data size: (3201, 3)
# Filtered data size for trex: (1979, 3)
# Processing ushy, initial data size: (8, 3)
# Filtered data size for ushy: (8, 3)
# Processing smbk, initial data size: (424, 3)
# Filtered data size for smbk: (424, 3)
# Processing mgnx, initial data size: (1031, 3)
# Filtered data size for mgnx: (1031, 3)
# Processing bw, initial data size: (598, 3)
# Filtered data size for bw: (598, 3)
# Processing rodm, initial data size: (524, 3)
# Filtered data size for rodm: (524, 3)
# Processing cway, initial data size: (868, 3)
# Filtered data size for cway: (868, 3)
# Processing tdc, initial data size: (2561, 3)
# Filtered data size for tdc: (1979, 3)
# Processing atto, initial data size: (785, 3)
# Filtered data size for atto: (785, 3)
# Processing sab, initial data size: (196, 3)
# Filtered data size for sab: (196, 3)
# Processing jsynw, initial data size: (230, 3)
# Filtered data size for jsynw: (230, 3)
# Processing ftag, initial data size: (1805, 3)
# Filtered data size for ftag: (1805, 3)
# Processing shlm, initial data size: (3201, 3)
# Filtered data size for shlm: (1979, 3)
# Processing ddr, initial data size: (3201, 3)
# Filtered data size for ddr: (1979, 3)
# Processing lgcy, initial data size: (2729, 3)
# Filtered data size for lgcy: (1979, 3)
# Processing pre_g, initial data size: (384, 3)
# Filtered data size for pre_g: (384, 3)
# Processing oxbr, initial data size: (849, 3)
# Filtered data size for oxbr: (849, 3)
# Processing vod, initial data size: (3201, 3)
# Filtered data size for vod: (1979, 3)
# Processing prgs, initial data size: (3201, 3)
# Filtered data size for prgs: (1979, 3)
# Processing esgg, initial data size: (164, 3)
# Filtered data size for esgg: (164, 3)
# Processing zbk, initial data size: (997, 3)
# Filtered data size for zbk: (997, 3)
# Processing lndc, initial data size: (3201, 3)
# Filtered data size for lndc: (1979, 3)
# Processing cnfr, initial data size: (535, 3)
# Filtered data size for cnfr: (535, 3)
# Processing rf, initial data size: (4147, 3)
# Filtered data size for rf: (1980, 3)
# Processing ras_b, initial data size: (1796, 3)
# Filtered data size for ras_b: (1796, 3)
# Processing zb_h, initial data size: (1137, 3)
# Filtered data size for zb_h: (1137, 3)
# Processing ttph, initial data size: (1173, 3)
# Filtered data size for ttph: (1173, 3)
# Processing hmn, initial data size: (3201, 3)
# Filtered data size for hmn: (1979, 3)
# Processing mtbc, initial data size: (818, 3)
# Filtered data size for mtbc: (818, 3)
# Processing bjri, initial data size: (3201, 3)
# Filtered data size for bjri: (1979, 3)
# Processing ldos, initial data size: (2790, 3)
# Filtered data size for ldos: (1979, 3)
# Processing aldx, initial data size: (887, 3)
# Filtered data size for aldx: (887, 3)
# Processing egl, initial data size: (1338, 3)
# Filtered data size for egl: (1338, 3)
# Processing cclp, initial data size: (1613, 3)
# Filtered data size for cclp: (1613, 3)
# Processing snna, initial data size: (76, 3)
# Filtered data size for snna: (76, 3)
# Processing lpg, initial data size: (887, 3)
# Filtered data size for lpg: (887, 3)
# Processing cbm, initial data size: (3201, 3)
# Filtered data size for cbm: (1979, 3)
# Processing cemb, initial data size: (1344, 3)
# Filtered data size for cemb: (1344, 3)
# Processing mtt, initial data size: (2174, 3)
# Filtered data size for mtt: (1979, 3)
# Processing shos, initial data size: (1276, 3)
# Filtered data size for shos: (1276, 3)
# Processing faln, initial data size: (318, 3)
# Filtered data size for faln: (318, 3)
# Processing hfbl, initial data size: (1576, 3)
# Filtered data size for hfbl: (1031, 3)
# Processing sona, initial data size: (2537, 3)
# Filtered data size for sona: (1890, 3)
# Processing ttgt, initial data size: (2643, 3)
# Filtered data size for ttgt: (1979, 3)
# Processing rogs, initial data size: (400, 3)
# Filtered data size for rogs: (400, 3)
# Processing gsjy, initial data size: (343, 3)
# Filtered data size for gsjy: (343, 3)
# Processing ai, initial data size: (3201, 3)
# Filtered data size for ai: (1979, 3)
# Processing vhi, initial data size: (3201, 3)
# Filtered data size for vhi: (1979, 3)
# Processing klic, initial data size: (3201, 3)
# Filtered data size for klic: (1979, 3)
# Processing andaw, initial data size: (190, 3)
# Filtered data size for andaw: (190, 3)
# Processing hive, initial data size: (915, 3)
# Filtered data size for hive: (915, 3)
# Processing flws, initial data size: (3201, 3)
# Filtered data size for flws: (1979, 3)
# Processing nusc, initial data size: (227, 3)
# Filtered data size for nusc: (227, 3)
# Processing etsy, initial data size: (651, 3)
# Filtered data size for etsy: (651, 3)
# Processing bfit, initial data size: (88, 3)
# Filtered data size for bfit: (88, 3)
# Processing newa, initial data size: (75, 3)
# Filtered data size for newa: (75, 3)
# Processing gjh, initial data size: (1287, 3)
# Filtered data size for gjh: (1287, 3)
# Processing cdor, initial data size: (3134, 3)
# Filtered data size for cdor: (1917, 3)
# Processing bscp, initial data size: (513, 3)
# Filtered data size for bscp: (513, 3)
# Processing jmba, initial data size: (3045, 3)
# Filtered data size for jmba: (1979, 3)
# Processing bdn, initial data size: (3201, 3)
# Filtered data size for bdn: (1979, 3)
# Processing vvpr, initial data size: (159, 3)
# Filtered data size for vvpr: (159, 3)
# Processing nesr, initial data size: (84, 3)
# Filtered data size for nesr: (84, 3)
# Processing iamxr, initial data size: (14, 3)
# Filtered data size for iamxr: (14, 3)
# Processing mpacu, initial data size: (148, 3)
# Filtered data size for mpacu: (148, 3)
# Processing aoi, initial data size: (3201, 3)
# Filtered data size for aoi: (1979, 3)
# Processing ufcs, initial data size: (3201, 3)
# Filtered data size for ufcs: (1979, 3)
# Processing cy, initial data size: (3201, 3)
# Filtered data size for cy: (1979, 3)
# Processing ship, initial data size: (1534, 3)
# Filtered data size for ship: (1534, 3)
# Processing key_i, initial data size: (228, 3)
# Filtered data size for key_i: (228, 3)
# Processing obln, initial data size: (278, 3)
# Filtered data size for obln: (278, 3)
# Processing rnr_c, initial data size: (1812, 3)
# Filtered data size for rnr_c: (1812, 3)
# Processing bwa, initial data size: (3201, 3)
# Filtered data size for bwa: (1979, 3)
# Processing arco, initial data size: (1654, 3)
# Filtered data size for arco: (1654, 3)
# Processing wday, initial data size: (1279, 3)
# Filtered data size for wday: (1279, 3)
# Processing bhlb, initial data size: (3201, 3)
# Filtered data size for bhlb: (1979, 3)
# Processing cjjd, initial data size: (1946, 3)
# Filtered data size for cjjd: (1919, 3)
# Processing bfs_c, initial data size: (1163, 3)
# Filtered data size for bfs_c: (1163, 3)
# Processing pxd, initial data size: (3201, 3)
# Filtered data size for pxd: (1979, 3)
# Processing lpth, initial data size: (3135, 3)
# Filtered data size for lpth: (1969, 3)
# Processing ssc, initial data size: (1367, 3)
# Filtered data size for ssc: (1367, 3)
# Processing rtnb, initial data size: (212, 3)
# Filtered data size for rtnb: (212, 3)
# Processing axu, initial data size: (2908, 3)
# Filtered data size for axu: (1979, 3)
# Processing blbd, initial data size: (815, 3)
# Filtered data size for blbd: (815, 3)
# Processing swp, initial data size: (121, 3)
# Filtered data size for swp: (121, 3)
# Processing icpt, initial data size: (1279, 3)
# Filtered data size for icpt: (1279, 3)
# Processing fcre, initial data size: (1007, 3)
# Filtered data size for fcre: (1007, 3)
# Processing trq, initial data size: (3201, 3)
# Filtered data size for trq: (1979, 3)
# Processing petq, initial data size: (80, 3)
# Filtered data size for petq: (80, 3)
# Processing krnt, initial data size: (660, 3)
# Filtered data size for krnt: (660, 3)
# Processing synl, initial data size: (3141, 3)
# Filtered data size for synl: (1969, 3)
# Processing hbmd, initial data size: (928, 3)
# Filtered data size for hbmd: (928, 3)
# Processing ufs, initial data size: (3201, 3)
# Filtered data size for ufs: (1979, 3)
# Processing ubnk, initial data size: (3082, 3)
# Filtered data size for ubnk: (1980, 3)
# Processing kth, initial data size: (1411, 3)
# Filtered data size for kth: (1411, 3)
# Processing twin, initial data size: (3192, 3)
# Filtered data size for twin: (1979, 3)
# Processing gme, initial data size: (3201, 3)
# Filtered data size for gme: (1979, 3)
# Processing wmt, initial data size: (11443, 3)
# Filtered data size for wmt: (1980, 3)
# Processing rga, initial data size: (3201, 3)
# Filtered data size for rga: (1979, 3)
# Processing psec, initial data size: (3201, 3)
# Filtered data size for psec: (1979, 3)
# Processing bcc, initial data size: (1202, 3)
# Filtered data size for bcc: (1202, 3)
# Processing ccc, initial data size: (3201, 3)
# Filtered data size for ccc: (1979, 3)
# Processing htht, initial data size: (1923, 3)
# Filtered data size for htht: (1923, 3)
# Processing fiv, initial data size: (224, 3)
# Filtered data size for fiv: (224, 3)
# Processing hafc, initial data size: (1484, 3)
# Filtered data size for hafc: (1484, 3)
# Processing wlfc, initial data size: (3154, 3)
# Filtered data size for wlfc: (1971, 3)
# Processing sga, initial data size: (3169, 3)
# Filtered data size for sga: (1955, 3)
# Processing tmus, initial data size: (2663, 3)
# Filtered data size for tmus: (1979, 3)
# Processing hdlv, initial data size: (780, 3)
# Filtered data size for hdlv: (780, 3)
# Processing chfn, initial data size: (2963, 3)
# Filtered data size for chfn: (1906, 3)
# Processing bpl, initial data size: (3201, 3)
# Filtered data size for bpl: (1979, 3)
# Processing rtn, initial data size: (9043, 3)
# Filtered data size for rtn: (1980, 3)
# Processing wala, initial data size: (352, 3)
# Filtered data size for wala: (352, 3)
# Processing flgb, initial data size: (3, 3)
# Filtered data size for flgb: (3, 3)
# Processing nmr, initial data size: (3201, 3)
# Filtered data size for nmr: (1979, 3)
# Processing stn, initial data size: (3112, 3)
# Filtered data size for stn: (1979, 3)
# Processing avnw, initial data size: (2718, 3)
# Filtered data size for avnw: (1979, 3)
# Processing atac, initial data size: (38, 3)
# Filtered data size for atac: (38, 3)
# Processing itri, initial data size: (3201, 3)
# Filtered data size for itri: (1979, 3)
# Processing oia, initial data size: (3201, 3)
# Filtered data size for oia: (1979, 3)
# Processing cpl, initial data size: (3201, 3)
# Filtered data size for cpl: (1979, 3)
# Processing splp_t, initial data size: (20, 3)
# Filtered data size for splp_t: (20, 3)
# Processing bbt_d, initial data size: (1391, 3)
# ...
# Filtered data size for icow: (100, 3)
# Processing vbf, initial data size: (3201, 3)
# Filtered data size for vbf: (1979, 3)
# Processing kf, initial data size: (3200, 3)
# Filtered data size for kf: (1978, 3)
# Processing xpl, initial data size: (2978, 3)
# Filtered data size for xpl: (1975, 3)
# Processing ry_s-cl, initial data size: (48, 3)
# Filtered data size for ry_s-cl: (48, 3)
# Processing dfs_b-cl, initial data size: (7, 3)
# Filtered data size for dfs_b-cl: (7, 3)
# Processing mbio, initial data size: (58, 3)
# Filtered data size for mbio: (58, 3)
# Processing bcom, initial data size: (2054, 3)
# Filtered data size for bcom: (1544, 3)
# Processing eip, initial data size: (3106, 3)
# Filtered data size for eip: (1945, 3)
# Processing nymtn, initial data size: (21, 3)
# Filtered data size for nymtn: (21, 3)
# Processing q, initial data size: (1138, 3)
# Filtered data size for q: (1138, 3)
# Processing igeb, initial data size: (85, 3)
# Filtered data size for igeb: (85, 3)
# Processing spvu, initial data size: (217, 3)
# Filtered data size for spvu: (217, 3)
# Processing tipt, initial data size: (1039, 3)
# Filtered data size for tipt: (1039, 3)
# Processing type, initial data size: (2596, 3)
# Filtered data size for type: (1979, 3)
# Processing bhb, initial data size: (3063, 3)
# Filtered data size for bhb: (1964, 3)
# Processing wrb_b, initial data size: (1140, 3)
# Filtered data size for wrb_b: (1140, 3)
# Processing wmgiz, initial data size: (994, 3)
# Filtered data size for wmgiz: (994, 3)
# Processing jpm_a, initial data size: (1187, 3)
# Filtered data size for jpm_a: (1187, 3)
# Processing nextw, initial data size: (238, 3)
# Filtered data size for nextw: (238, 3)
# Processing aau, initial data size: (3177, 3)
# Filtered data size for aau: (1979, 3)
# Processing cna, initial data size: (3201, 3)
# Filtered data size for cna: (1979, 3)
# Processing snp, initial data size: (3201, 3)
# Filtered data size for snp: (1979, 3)
# Processing nwl, initial data size: (8400, 3)
# Filtered data size for nwl: (1980, 3)
# Processing irm, initial data size: (3201, 3)
# Filtered data size for irm: (1979, 3)
# Processing pacw, initial data size: (3201, 3)
# Filtered data size for pacw: (1979, 3)
# Processing lvhi, initial data size: (325, 3)
# Filtered data size for lvhi: (325, 3)
# Processing eos, initial data size: (3201, 3)
# Filtered data size for eos: (1979, 3)
# Processing rnp, initial data size: (3201, 3)
# Filtered data size for rnp: (1979, 3)
# Processing heq, initial data size: (1626, 3)
# Filtered data size for heq: (1626, 3)
# Processing bncl, initial data size: (2602, 3)
# Filtered data size for bncl: (1979, 3)
# Processing mod, initial data size: (3201, 3)
# Filtered data size for mod: (1979, 3)
# Processing qrvo, initial data size: (696, 3)
# Filtered data size for qrvo: (696, 3)
# Processing hei-a, initial data size: (1819, 3)
# Filtered data size for hei-a: (1819, 3)
# Processing odc, initial data size: (3169, 3)
# Filtered data size for odc: (1979, 3)
# Processing sach, initial data size: (190, 3)
# Filtered data size for sach: (190, 3)
# Processing osbc, initial data size: (3200, 3)
# Filtered data size for osbc: (1978, 3)
# Processing golf, initial data size: (262, 3)
# Filtered data size for golf: (262, 3)
# Processing ctrp, initial data size: (3201, 3)
# Filtered data size for ctrp: (1979, 3)
# Processing prk, initial data size: (3201, 3)
# Filtered data size for prk: (1979, 3)
# Processing patk, initial data size: (3041, 3)
# Filtered data size for patk: (1953, 3)
# Processing gsh, initial data size: (3201, 3)
# Filtered data size for gsh: (1979, 3)
# Processing orbc, initial data size: (2775, 3)
# Filtered data size for orbc: (1979, 3)
# Processing daio, initial data size: (3108, 3)
# Filtered data size for daio: (1907, 3)
# Processing xshd, initial data size: (236, 3)
# Filtered data size for xshd: (236, 3)
# Processing tho, initial data size: (3201, 3)
# Filtered data size for tho: (1979, 3)
# Processing corr_a, initial data size: (679, 3)
# Filtered data size for corr_a: (679, 3)
# Processing cuba, initial data size: (3153, 3)
# Filtered data size for cuba: (1970, 3)
# Processing hall, initial data size: (3088, 3)
# Filtered data size for hall: (1979, 3)
# Processing san_i, initial data size: (1753, 3)
# Filtered data size for san_i: (1753, 3)
# Processing cil, initial data size: (380, 3)
# Filtered data size for cil: (380, 3)
# Processing veru, initial data size: (3161, 3)
# Filtered data size for veru: (1978, 3)
# Processing psb_x, initial data size: (36, 3)
# Filtered data size for psb_x: (36, 3)
# Processing rmcf, initial data size: (3198, 3)
# Filtered data size for rmcf: (1976, 3)
# Processing insg, initial data size: (3201, 3)
# Filtered data size for insg: (1979, 3)
# Processing ubp_f-cl, initial data size: (24, 3)
# Filtered data size for ubp_f-cl: (24, 3)
# Processing pfi, initial data size: (2770, 3)
# Filtered data size for pfi: (1964, 3)
# Processing mhi, initial data size: (3201, 3)
# Filtered data size for mhi: (1979, 3)
# Processing vpg, initial data size: (1861, 3)
# Filtered data size for vpg: (1861, 3)
# Processing nfbk, initial data size: (2520, 3)
# Filtered data size for nfbk: (1979, 3)
# Processing ocn, initial data size: (3201, 3)
# Filtered data size for ocn: (1979, 3)
# Processing thff, initial data size: (3201, 3)
# Filtered data size for thff: (1979, 3)
# Processing rvlt, initial data size: (3028, 3)
# Filtered data size for rvlt: (1979, 3)
# Processing crto, initial data size: (1017, 3)
# Filtered data size for crto: (1017, 3)
# Processing wpg, initial data size: (871, 3)
# Filtered data size for wpg: (871, 3)
# Processing psxp, initial data size: (1087, 3)
# Filtered data size for psxp: (1087, 3)
# File /Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/mapi.us.txt is empty. Skipping.
# Processing gte, initial data size: (3019, 3)
# Filtered data size for gte: (1979, 3)
# Processing wtt, initial data size: (3192, 3)
# Filtered data size for wtt: (1973, 3)
# Processing ehth, initial data size: (2790, 3)
# Filtered data size for ehth: (1979, 3)
# Processing heuv, initial data size: (442, 3)
# Filtered data size for heuv: (442, 3)
# Processing c_c, initial data size: (1167, 3)
# Filtered data size for c_c: (1167, 3)
# Processing sito, initial data size: (571, 3)
# Filtered data size for sito: (571, 3)
# Processing gsd, initial data size: (442, 3)
# Filtered data size for gsd: (442, 3)
# Processing exc, initial data size: (9547, 3)
# Filtered data size for exc: (1980, 3)
# Processing gww, initial data size: (8295, 3)
# Filtered data size for gww: (1980, 3)
# Processing evar, initial data size: (883, 3)
# Filtered data size for evar: (883, 3)
# Processing moh, initial data size: (3201, 3)
# Filtered data size for moh: (1979, 3)
# Processing dxc, initial data size: (155, 3)
# Filtered data size for dxc: (155, 3)
# Processing oflx, initial data size: (3029, 3)
# Filtered data size for oflx: (1971, 3)
# Processing hdrw, initial data size: (434, 3)
# Filtered data size for hdrw: (434, 3)
# Processing xel, initial data size: (4335, 3)
# Filtered data size for xel: (1980, 3)
# Processing lvhe, initial data size: (241, 3)
# Filtered data size for lvhe: (241, 3)
# Processing fisv, initial data size: (6964, 3)
# Filtered data size for fisv: (1980, 3)
# Processing ibmk, initial data size: (546, 3)
# Filtered data size for ibmk: (546, 3)
# Processing ivr, initial data size: (2111, 3)
# Filtered data size for ivr: (1979, 3)
# Processing nss, initial data size: (1208, 3)
# Filtered data size for nss: (1208, 3)
# Processing pfbi, initial data size: (3027, 3)
# Filtered data size for pfbi: (1963, 3)
# Processing ctas, initial data size: (6962, 3)
# Filtered data size for ctas: (1980, 3)
# Processing pah, initial data size: (960, 3)
# Filtered data size for pah: (960, 3)
# Processing fdx, initial data size: (9547, 3)
# Filtered data size for fdx: (1980, 3)
# Processing dkl, initial data size: (1266, 3)
# Filtered data size for dkl: (1266, 3)
# Processing ford, initial data size: (3200, 3)
# Filtered data size for ford: (1978, 3)
# Processing jnce, initial data size: (201, 3)
# Filtered data size for jnce: (201, 3)
# Processing gladn, initial data size: (32, 3)
# Filtered data size for gladn: (32, 3)
# Processing flir, initial data size: (3201, 3)
# Filtered data size for flir: (1979, 3)
# Processing bdxa, initial data size: (123, 3)
# Filtered data size for bdxa: (123, 3)
# Processing ibp, initial data size: (945, 3)
# Filtered data size for ibp: (945, 3)
# Processing arna, initial data size: (3200, 3)
# Filtered data size for arna: (1978, 3)
# Processing regn, initial data size: (3200, 3)
# Filtered data size for regn: (1978, 3)
# Processing ncb, initial data size: (2130, 3)
# Filtered data size for ncb: (1967, 3)
# Processing scon, initial data size: (3201, 3)
# Filtered data size for scon: (1979, 3)
# Processing fti, initial data size: (3201, 3)
# Filtered data size for fti: (1979, 3)
# Processing mhe, initial data size: (2916, 3)
# Filtered data size for mhe: (1837, 3)
# Processing hbp, initial data size: (985, 3)
# Filtered data size for hbp: (985, 3)
# Processing home, initial data size: (322, 3)
# Filtered data size for home: (322, 3)
# Processing atos, initial data size: (1260, 3)
# Filtered data size for atos: (1260, 3)
# Processing plnt, initial data size: (573, 3)
# Filtered data size for plnt: (573, 3)
# Processing bgsf, initial data size: (636, 3)
# Filtered data size for bgsf: (636, 3)
# Processing hfc, initial data size: (1602, 3)
# Filtered data size for hfc: (1602, 3)
# Processing asna, initial data size: (3202, 3)
# Filtered data size for asna: (1980, 3)
# Processing rlgy, initial data size: (1280, 3)
# Filtered data size for rlgy: (1280, 3)
# Processing trmk, initial data size: (3201, 3)
# Filtered data size for trmk: (1979, 3)
# Processing reta, initial data size: (370, 3)
# Filtered data size for reta: (370, 3)
# Processing rbus, initial data size: (34, 3)
# Filtered data size for rbus: (34, 3)
# Processing bms, initial data size: (8346, 3)
# Filtered data size for bms: (1980, 3)
# File /Users/eoingaynard/Small-Cap-Scout/raw_data/Data/Stocks/ehr.us.txt is empty. Skipping.
# Processing ptnr, initial data size: (3192, 3)
# Filtered data size for ptnr: (1970, 3)
# Processing pfe, initial data size: (9042, 3)
# Filtered data size for pfe: (1980, 3)
# Processing thc, initial data size: (9042, 3)
# Filtered data size for thc: (1980, 3)
# Processing rso_b, initial data size: (1286, 3)
# Filtered data size for rso_b: (1286, 3)
# Processing aft, initial data size: (1684, 3)
# Filtered data size for aft: (1684, 3)
# Processing nati, initial data size: (3201, 3)
# Filtered data size for nati: (1979, 3)
# Processing dla, initial data size: (3173, 3)
# Filtered data size for dla: (1977, 3)
# Processing psb_t, initial data size: (1385, 3)
# Filtered data size for psb_t: (1385, 3)
# Processing tlp, initial data size: (3140, 3)
# Filtered data size for tlp: (1979, 3)
# Processing bwinb, initial data size: (3201, 3)
# Filtered data size for bwinb: (1979, 3)
# Processing bdc_b, initial data size: (315, 3)
# Filtered data size for bdc_b: (315, 3)
# Processing abg, initial data size: (3201, 3)
# Filtered data size for abg: (1979, 3)
# Processing cms, initial data size: (8280, 3)
# Filtered data size for cms: (1979, 3)
# Processing dhr, initial data size: (7562, 3)
# Filtered data size for dhr: (1980, 3)
# Processing gsat, initial data size: (2776, 3)
# Filtered data size for gsat: (1979, 3)
# Processing jd, initial data size: (877, 3)
# Filtered data size for jd: (877, 3)
# Processing tenx, initial data size: (3201, 3)
# Filtered data size for tenx: (1979, 3)
# Processing sce_h, initial data size: (929, 3)
# Filtered data size for sce_h: (929, 3)
# Processing lsxmk, initial data size: (398, 3)
# Filtered data size for lsxmk: (398, 3)
# Processing orpn, initial data size: (829, 3)
# Filtered data size for orpn: (829, 3)
# Processing wat, initial data size: (5531, 3)
# Filtered data size for wat: (1980, 3)
# Processing tlys, initial data size: (1391, 3)
# Filtered data size for tlys: (1391, 3)
# Processing tgp_a, initial data size: (275, 3)
# Filtered data size for tgp_a: (275, 3)
# Processing sor, initial data size: (3201, 3)
# Filtered data size for sor: (1979, 3)
# Processing elon, initial data size: (3199, 3)
# Filtered data size for elon: (1977, 3)
# Processing ahgp, initial data size: (2899, 3)
# Filtered data size for ahgp: (1979, 3)
# Processing sb_b, initial data size: (701, 3)
# Filtered data size for sb_b: (701, 3)
# Processing ooma, initial data size: (587, 3)
# Filtered data size for ooma: (587, 3)
# Processing ht, initial data size: (3201, 3)
# Filtered data size for ht: (1979, 3)
# Processing rxn, initial data size: (1416, 3)
# Filtered data size for rxn: (1416, 3)
# Processing ontxw, initial data size: (151, 3)
# Filtered data size for ontxw: (151, 3)
# Processing pcg_b, initial data size: (1318, 3)
# Filtered data size for pcg_b: (1318, 3)
# Processing tpge-u, initial data size: (97, 3)
# Filtered data size for tpge-u: (97, 3)
# Processing nea, initial data size: (3201, 3)
# Filtered data size for nea: (1979, 3)
# Processing fitbi, initial data size: (982, 3)
# Filtered data size for fitbi: (982, 3)
# Processing dwin, initial data size: (424, 3)
# Filtered data size for dwin: (424, 3)
# Processing asx, initial data size: (3200, 3)
# Filtered data size for asx: (1978, 3)
# Processing dplo, initial data size: (779, 3)
# Filtered data size for dplo: (779, 3)
# Processing faro, initial data size: (3201, 3)
# Filtered data size for faro: (1979, 3)
# Processing wpg_h, initial data size: (677, 3)
# Filtered data size for wpg_h: (677, 3)
# Processing awk, initial data size: (2408, 3)
# Filtered data size for awk: (1979, 3)
# Processing hds, initial data size: (1104, 3)
# Filtered data size for hds: (1104, 3)
# Processing fwonk, initial data size: (831, 3)
# Filtered data size for fwonk: (831, 3)
# Processing crvs, initial data size: (415, 3)
# Filtered data size for crvs: (415, 3)
# Processing ltea, initial data size: (325, 3)
# Filtered data size for ltea: (325, 3)
# Processing mtls, initial data size: (854, 3)
# Filtered data size for mtls: (854, 3)
# Processing ns_b, initial data size: (134, 3)
# Filtered data size for ns_b: (134, 3)
# Processing camt, initial data size: (3174, 3)
# Filtered data size for camt: (1976, 3)
# Processing emo, initial data size: (1616, 3)
# Filtered data size for emo: (1616, 3)
# Processing hpq, initial data size: (12075, 3)
# Filtered data size for hpq: (1980, 3)
# Processing pirs, initial data size: (669, 3)
# Filtered data size for pirs: (669, 3)
# Processing ival, initial data size: (720, 3)
# Filtered data size for ival: (720, 3)
# Processing chn, initial data size: (3201, 3)
# Filtered data size for chn: (1979, 3)
# Processing omex, initial data size: (3201, 3)
# Filtered data size for omex: (1979, 3)
# Processing roic, initial data size: (2495, 3)
# Filtered data size for roic: (1979, 3)
# Processing dmo, initial data size: (1945, 3)
# Filtered data size for dmo: (1945, 3)
# Processing uzb, initial data size: (736, 3)
# Filtered data size for uzb: (736, 3)
# Processing nbl, initial data size: (3201, 3)
# Filtered data size for nbl: (1979, 3)
# Processing nrim, initial data size: (3170, 3)
# Filtered data size for nrim: (1972, 3)
# Processing lmat, initial data size: (2733, 3)
# Filtered data size for lmat: (1968, 3)
# Processing atu, initial data size: (3201, 3)
# Filtered data size for atu: (1979, 3)
# Processing jhy, initial data size: (579, 3)
# Filtered data size for jhy: (579, 3)
# Processing xco, initial data size: (2961, 3)
# Filtered data size for xco: (1979, 3)
# Processing mik, initial data size: (852, 3)
# Filtered data size for mik: (852, 3)
# Processing apf, initial data size: (3200, 3)
# Filtered data size for apf: (1978, 3)
# Data processing complete. Results saved to /Users/eoingaynard/Small-Cap-Scout/raw_data/processed_data.csv.
# First 5 rows of the processed data:
#   Ticker    Month  Monthly_Avg_Close  Monthly_Volume_Total  \
# 0    iba  2010-01          20.339737                 87729
# 1    iba  2010-02          18.075000                121023
# 2    iba  2010-03          18.729565                371489
# 3    iba  2010-04          18.811762                177267
# 4    iba  2010-05          18.390950                266529
#
#    Monthly_Volume_Avg  Monthly_Volatility
# 0         4617.315789            0.165217
# 1         6369.631579            0.251822
# 2        16151.695652            0.207545
# 3         8441.285714            0.204060
# 4        13326.450000            0.231837

# %%
# Let's load the CSV file into a DataFrame
processed_df = pd.read_csv(output_file)

# Display the first 5 rows of the DataFrame
print(processed_df.tail())
# Out:
#        Ticker    Month  Monthly_Avg_Close  Monthly_Volume_Total  \
# 467050    apf  2017-07          16.892010                220196
# 467051    apf  2017-08          17.092074                559754
# 467052    apf  2017-09          17.304750                431482
# 467053    apf  2017-10          17.839318                571405
# 467054    apf  2017-11          18.087013                 83924
#
#         Monthly_Volume_Avg  Monthly_Volatility
# 467050        11009.800000            0.062602
# 467051        24337.130435            0.067810
# 467052        21574.100000            0.049952
# 467053        25972.954545            0.072105
# 467054        10490.500000            0.066259

# %%
# Define the path to the processed data CSV file
processed_data_file = os.path.expanduser('~/Small-Cap-Scout/raw_data/processed_data.csv')

# Define the path to the new CSV file with tickers
tickers_file = os.path.expanduser('~/Small-Cap-Scout/raw_data/tickers.csv')

# Read the processed data CSV file
try:
    df = pd.read_csv(processed_data_file)

    # Ensure the 'Ticker' column exists
    if 'Ticker' in df.columns:
        # Get unique tickers
        unique_tickers = df['Ticker'].unique()

        # Create a DataFrame for tickers
        tickers_df = pd.DataFrame(unique_tickers, columns=['Ticker'])

        # Save the tickers to a new CSV file
        tickers_df.to_csv(tickers_file, index=False)
        print(f"Tickers have been successfully saved to {tickers_file}.")
    else:
        print("The 'Ticker' column is missing in the processed data file.")
except FileNotFoundError:
    print(f"The file {processed_data_file} does not exist. Please check the file path.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Tickers have been successfully saved to /Users/eoingaynard/Small-Cap-Scout/raw_data/tickers.csv.

# %%
 # Read the newly created tickers CSV file
tickers_df_loaded = pd.read_csv(tickers_file)

# Show the first lines of the tickers DataFrame
print("First 5 lines of the tickers DataFrame:")
print(tickers_df_loaded.head())
# Out:
# First 5 lines of the tickers DataFrame:
#   Ticker
# 0    iba
# 1    wpz
# 2   opnt
# 3   indf
# 4   flic
